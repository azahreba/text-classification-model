# %%
docs_path = r'C:\Users\Artur_Zahreba\Desktop\WorkFusion\P&G\sample email June 15\DocsHtml'
txts_path = r'C:\Users\Artur_Zahreba\Desktop\WorkFusion\P&G\sample email June 15\text_samples'

with open(txts_path + '\\' + 'Antwort  RE  Purchase order 4310049184.msg.txt', 'r') as ffile:
    txt = ffile.read()
    print(txt)
# Out:
# From: P_Doerfler@gebr-heinemann.de
# Sent: Thu Jun 15 05:08:56 CEST 2017
# To: Chan, MeiLay
# Cc: J_Goncalves@gebr-heinemann.de; Lu, Darryl; Pannese, Marianna; PuG-Singapore@list.gebr-heinemann.de
# Subject: Antwort: RE: Purchase order 4310049184
#
# Dear Carina,
#
# Please find attached PO including price.
#
# Best regards
# Pascal
#
#
# Best regards / Mit freundlichem GruЯ
#
# Pascal Dцrfler
# Supplier Order Manager Perfume & Cosmetics
# Fulfillment
#
#
#
# KoreastraЯe 3
# 20457 Hamburg
# Telefon +49 (40) 30 10 21 509
#
# P_Doerfler@gebr-heinemann.de
# www.gebr-heinemann.de
#
#
#
#
# Von:        "Chan, MeiLay" <chan.m.6@pg.com>
# An:        "p_doerfler@gebr-heinemann.de"
# <p_doerfler@gebr-heinemann.de>, "PuG-Singapore@list.gebr-heinemann.de"
# <PuG-Singapore@list.gebr-heinemann.de>, "J_Goncalves@gebr-heinemann.de"
# <J_Goncalves@gebr-heinemann.de>
# Kopie:        "Lu, Darryl" <lu.d.6@pg.com>, "Pannese, Marianna"
# <pannese.m@pg.com>
# Datum:        08.06.2017 05:06
# ...

# %%
with open(r'C:\Users\Artur_Zahreba\Desktop\WorkFusion\P&G\sample email June 15\Antwort  RE  Purchase order 4310049184.txt', "w+") as txt_file:
        txt_file.write(txt.encode('ascii', 'replace').decode('utf-8').replace('?', ''))
#         txt_file.write(txt)

        txt_file.close()
# Out:
# <class 'str'>
